# %%
import os 
import sys
import random
import numpy as np
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim

# SUMO-RL
if "SUMO_HOME" in os.environ:
    tools = os.path.join(os.environ["SUMO_HOME"], "tools")
    sys.path.append(tools)

else:
    sys.exit("Please declare the environment variable 'SUMO_HOME'")

from sumo_rl import SumoEnvironment

print("SUMO-RL imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"SUMO_HOME: {os.environ['SUMO_HOME']}")
# Out:
# SUMO-RL imported successfully!
# PyTorch version: 2.10.0+cu128
# SUMO_HOME: /usr/share/sumo

# %%
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim)
        )

    def forward(self, x):
        return self.net(x)
    
state_dim = 11
action_dim = 4

q_net = QNetwork(state_dim, action_dim)
target_net = QNetwork(state_dim, action_dim)

target_net.load_state_dict(q_net.state_dict())

dummy_state = torch.FloatTensor(np.random.rand(state_dim))
q_values = q_net(dummy_state)

print(f"Q-Network Architecture:\n{q_net}")
print(f"\nInput state shape: {dummy_state.shape}")
print(f"outptut q-values {q_values}")
print(f"Output Q-values shape: {q_values.shape}")
print(f"\nTarget network weights match Q-network: "
      f"{all(torch.equal(p1, p2) for p1, p2 in zip(q_net.parameters(), target_net.parameters()))}")
# Out:
# Q-Network Architecture:
# QNetwork(
#   (net): Sequential(
#     (0): Linear(in_features=11, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=4, bias=True)
#   )
# )
#
# Input state shape: torch.Size([11])
# outptut q-values tensor([-0.0727, -0.1507,  0.1983,  0.0830], grad_fn=<ViewBackward0>)
# Output Q-values shape: torch.Size([4])
#
# Target network weights match Q-network: True

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size = 32):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (torch.FloatTensor(np.array(states)),
                torch.LongTensor(np.array(actions)),
                torch.FloatTensor(np.array(rewards)),
                torch.FloatTensor(np.array(next_states)),
                torch.FloatTensor(np.array(dones)))

    def __len__(self):
        return len(self.buffer)
    
buffer = ReplayBuffer(capacity=5000)
for i in range(100):
    state      = np.random.rand(state_dim)
    action     = np.random.randint(action_dim)
    reward     = np.random.uniform(-1, 1)
    next_state = np.random.rand(state_dim)
    done       = False
    buffer.push(state, action, reward, next_state, done)

print(f"Buffer size after 100 pushes: {len(buffer)}")

states, actions, rewards, next_states, dones = buffer.sample(32)

print(f"Buffer Size after 100 pushes: {len(buffer)}")
print(f"\n sampled batch shapes:")
print(f"  States: {states.shape}")
print(f"  Actions: {actions.shape}")
print(f"  Rewards: {rewards.shape}")
print(f"  Next States: {next_states.shape}")
print(f"  Dones: {dones.shape}")
# Out:
# Buffer size after 100 pushes: 100
# Buffer Size after 100 pushes: 100
#
#  sampled batch shapes:
#   States: torch.Size([32, 11])
#   Actions: torch.Size([32])
#   Rewards: torch.Size([32])
#   Next States: torch.Size([32, 11])
#   Dones: torch.Size([32])

# %%
class DQNAgent:
    def __init__(self, state_dim, action_dim):
        self.q_net = QNetwork(state_dim, action_dim)
        self.target_net = QNetwork(state_dim, action_dim)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.target_net.eval()  # Set target net to evaluation mode

        self.buffer = ReplayBuffer(capacity=5000)
        self.optimizer = optim.Adam(self.q_net.parameters(), lr=0.00025)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.batch_size = 32

        self.action_dim = action_dim
        self.losses = []

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.action_dim - 1)
        else:
            state_tesnor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                q_values = self.q_net(state_tesnor)
            return q_values.argmax().item()
        
    def train_step(self):
        if len(self.buffer) < self.batch_size:
            return None

        states, actions, rewards, next_states, dones = self.buffer.sample(self.batch_size)

        current_q = self.q_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            max_next_q = self.target_net(next_states).max(1)[0]
            target_q = rewards + self.gamma * max_next_q * (1 - dones)

        loss = nn.MSELoss()(current_q, target_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.losses.append(loss.item())
        return loss.item()
    
    def update_target_network(self):
        self.target_net.load_state_dict(self.q_net.state_dict())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

agent = DQNAgent(state_dim = 11, action_dim = 4)

for i in range(100):
    state = np.random.rand(11)
    action = np.random.randint(4)
    reward = np.random.uniform(-1, 1)
    next_state = np.random.rand(11)
    done = False
    agent.buffer.push(state, action, reward, next_state, done)

state = np.random.rand(11)
action = agent.select_action(state)

loss = agent.train_step()

print(f"Agent initialized!!!")
print(f"\nepsilon: {agent.epsilon}")
print(f"buffer size: {len(agent.buffer)}")
print(f"selected action: {action} out off {agent.action_dim} possible actions")
print(f"training loss: {loss:.4f}")
print(f"\nQ-network: {sum(p.numel() for p in agent.q_net.parameters())} parameters")
# Out:
# Agent initialized!!!
#
# epsilon: 1.0
# buffer size: 100
# selected action: 0 out off 4 possible actions
# training loss: 0.4365
#
# Q-network: 5188 parameters

# %%
# ─────────────────────────────────────────
# VANILLA DQN v2 — IMPROVED HYPERPARAMETERS
# Changes from v1:
# 1. epsilon start: 1.0  → 0.1
# 2. buffer size:   5000 → 50000
# 3. target update: every 10 episodes → every 1000 steps
# 4. learning rate: 0.00025 → 0.001
# ─────────────────────────────────────────

class DQNAgentV2:
    def __init__(self, state_dim, action_dim):
        # Networks
        self.q_net      = QNetwork(state_dim, action_dim)
        self.target_net = QNetwork(state_dim, action_dim)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.target_net.eval()

        # Replay buffer — 10x larger than v1
        self.buffer = ReplayBuffer(capacity=50000)

        # Optimizer — higher lr matching SB3
        self.optimizer = optim.Adam(self.q_net.parameters(), lr=0.001)

        # Hyperparameters
        self.gamma         = 0.99
        self.epsilon       = 0.1      # v1 was 1.0
        self.epsilon_min   = 0.01
        self.epsilon_decay = 0.995
        self.batch_size    = 32
        self.action_dim    = action_dim
        self.losses        = []

    def select_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.action_dim - 1)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            with torch.no_grad():
                q_values = self.q_net(state_tensor)
            return q_values.argmax().item()

    def train_step(self):
        if len(self.buffer) < self.batch_size:
            return None
        states, actions, rewards, next_states, dones = self.buffer.sample(self.batch_size)
        current_q  = self.q_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        with torch.no_grad():
            max_next_q = self.target_net(next_states).max(1)[0]
            target_q   = rewards + self.gamma * max_next_q * (1 - dones)
        loss = nn.MSELoss()(current_q, target_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        self.losses.append(loss.item())
        return loss.item()

    def update_target_network(self):
        self.target_net.load_state_dict(self.q_net.state_dict())

    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
os.chdir("/home/tapan/classes/CS5180/Final_Project/sumo-rl")
print(f"Working directory: {os.getcwd()}")
net_file = "sumo_rl/nets/2way-single-intersection/single-intersection.net.xml"
print(f"Net file exists: {os.path.exists(net_file)}")
# Out:
# Working directory: /home/tapan/classes/CS5180/Final_Project/sumo-rl
# Net file exists: True

# %%
os.chdir("/home/tapan/classes/CS5180/Final_Project/sumo-rl")

SEEDS         = [42, 123, 456, 789, 1000]
TOTAL_SECONDS = 100000
TARGET_UPDATE_STEPS = 1000    # every 1000 steps instead of every 10 episodes
NET_FILE      = "sumo_rl/nets/2way-single-intersection/single-intersection.net.xml"
ROUTE_FILE    = "sumo_rl/nets/2way-single-intersection/single-intersection-vhvh.rou.xml"
OUTPUT_DIR    = "project/output/vanilla_dqn_v2"

os.makedirs(OUTPUT_DIR, exist_ok=True)

def train_one_seed_v2(seed):
    print(f"\n{'='*40}")
    print(f"Training Vanilla DQN v2 — Seed: {seed}")
    print(f"{'='*40}")

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    env = SumoEnvironment(
        net_file     = NET_FILE,
        route_file   = ROUTE_FILE,
        out_csv_name = f"{OUTPUT_DIR}/vanilla_dqn_v2_seed_{seed}",
        single_agent = True,
        use_gui      = False,
        num_seconds  = TOTAL_SECONDS,
    )

    state_dim  = env.observation_space.shape[0]
    action_dim = env.action_space.n
    print(f"State dim: {state_dim} | Action dim: {action_dim}")

    agent   = DQNAgentV2(state_dim=state_dim, action_dim=action_dim)
    episode = 0
    step    = 0

    episode_waittimes = []
    state, _ = env.reset()

    while True:
        action = agent.select_action(state)
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        step += 1

        agent.buffer.push(state, action, reward, next_state, float(done))

        # Train every 4 steps — more efficient
        if step % 4 == 0:
            agent.train_step()

        # Update target network every 1000 steps
        if step % TARGET_UPDATE_STEPS == 0:
            agent.update_target_network()
            print(f"  Step {step} — Target network updated")

        state = next_state

        if done:
            episode += 1
            agent.decay_epsilon()

            avg_wait = info.get("system_total_waiting_time", 0)
            episode_waittimes.append(avg_wait)
            print(f"  Episode {episode:3d} | "
                  f"Steps: {step:6d} | "
                  f"Epsilon: {agent.epsilon:.3f} | "
                  f"Waiting: {avg_wait:.1f}s | "
                  f"Buffer: {len(agent.buffer)}")

            state, _ = env.reset()

            if step >= TOTAL_SECONDS:
                break

    torch.save(agent.q_net.state_dict(),
               f"{OUTPUT_DIR}/vanilla_dqn_v2_model_seed_{seed}.pth")
    print(f"\nSeed {seed} complete. Model saved.")
    env.close()
    return episode_waittimes

# ── Run all seeds ────────────────────────
all_results_v2 = {}
for seed in SEEDS:
    all_results_v2[seed] = train_one_seed_v2(seed)

print("\n===== ALL VANILLA DQN V2 TRAINING COMPLETE =====")
print("\nFinal episode waiting times:")
for seed in SEEDS:
    final = all_results_v2[seed][-1] if all_results_v2[seed] else "N/A"
    print(f"  Seed {seed}: {final}s")
# Out:
# ========================================
# Training Vanilla DQN v2 — Seed: 42
# ========================================
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 3ms, vehicles TOT 0 ACT 0 BUF 0)
# State dim: 21 | Action dim: 4
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 2412 ACT 89 BUF 650)               Step 1000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~83000.00UPS, TraCI: 17ms, vehicles TOT 4401 ACT 83 BUF   Step 2000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~84000.00UPS, TraCI: 16ms, vehicles TOT 7382 ACT 84 BUF  Step 3000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~44000.00UPS, TraCI: 11ms, vehicles TOT 9736 ACT 44 BUF  Step 4000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~47000.00UPS, TraCI: 10ms, vehicles TOT 12161 ACT 47 BU  Step 5000 — Target network updated
# Step #26900.00 (2ms ~= 500.00*RT, ~48500.00UPS, TraCI: 19ms, vehicles TOT 15024 ACT 97 BUF  Step 6000 — Target network updated
# Step #31400.00 (2ms ~= 500.00*RT, ~46500.00UPS, TraCI: 21ms, vehicles TOT 18121 ACT 93 BUF  Step 7000 — Target network updated
# Step #36900.00 (2ms ~= 500.00*RT, ~45500.00UPS, TraCI: 20ms, vehicles TOT 21276 ACT 91 BUF  Step 8000 — Target network updated
# Step #4500  Step 9000 — Target network updated, TraCI: 16ms, vehicles TOT 26926 ACT 82 BUF00.00 (2ms ~= 500.00*RT, ~41500.00UPS, TraCI: 19ms, vehicles TOT 24429 ACT 83 BUF
# Step #49500.00 (3ms ~= 333.33*RT, ~27000.00UPS, TraCI: 18ms, vehicles TOT 29596 ACT 81 BUF  Step 10000 — Target network updated
# Step #54000.00 (3ms ~= 333.33*RT, ~28666.67UPS, TraCI: 17ms, vehicles TOT 32574 ACT 86 BUF  Step 11000 — Target network updated
# Step #58500.00 (2ms ~= 500.00*RT, ~47500.00UPS, TraCI: 20ms, vehicles TOT 35668 ACT 95 BUF  Step 12000 — Target network updated
# Step #63000.00 (3ms ~= 333.33*RT, ~30333.33UPS, TraCI: 18ms, vehicles TOT 38843 ACT 91 BUF  Step 13000 — Target network updated
# Step #67500.00 (2ms ~= 500.00*RT, ~45000.00UPS, TraCI: 17ms, vehicles TOT 41945 ACT 90 BUF  Step 14000 — Target network updated
# Step #72000.00 (3ms ~= 333.33*RT, ~36333.33UPS, TraCI: 21ms, vehicles TOT 45053 ACT 109 BU  Step 15000 — Target network updated
# Step #76500.00 (3ms ~= 333.33*RT, ~35666.67UPS, TraCI: 20ms, vehicles TOT 48195 ACT 107 BU  Step 16000 — Target network updated
# Step #81000.00 (2ms ~= 333.33*RT, ~35333.33UPS, TraCI: 22ms, vehicles TOT 51422 ACT 106 BU  Step 17000 — Target network updated
# Step #85500.00 (2ms ~= 333.33*RT, ~36000.00UPS, TraCI: 24ms, vehicles TOT 54636 ACT 108 BU  Step 18000 — Target network updated
# Step #94500.00 (3ms ~= 500.00*RT, ~53500.00UPS, TraCI: 22ms, vehicles TOT 60905 ACT 107 BU~= 333.33*RT, ~36666.67UPS, TraCI: 21ms, vehicles TOT 57931 ACT 110 BU  Step 19000 — Target network updated
# Step #99000.00 (2ms ~= 500.00*RT, ~50000.00UPS, TraCI: 19ms, vehicles TOT 64217 ACT 100 BU  Step 20000 — Target network updated
#   Episode   1 | Steps:  20000 | Epsilon: 0.100 | Waiting: 2628.0s | Buffer: 20000
# Step #100000.00 (1ms ~= 1000.00*RT, ~108000.00UPS, TraCI: 21ms, vehicles TOT 65026 ACT 108
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 3021 ACT 66 BUF 41)                Step 21000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 6171 ACT 75 BUF 17)                Step 22000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~63000.00UPS, TraCI: 13ms, vehicles TOT 9064 ACT 63 BUF  Step 23000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 11456 ACT 79 BUF 982)             Step 24000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~78000.00UPS, TraCI: 16ms, vehicles TOT 13612 ACT 78 BU  Step 25000 — Target network updated
# Step #26900.00 (2ms ~= 500.00*RT, ~71000.00UPS, TraCI: 28ms, vehicles TOT 16407 ACT 142 BU  Step 26000 — Target network updated
# Step #31400.00 (1ms ~= 1000.00*RT, ~121000.00UPS, TraCI: 24ms, vehicles TOT 19823 ACT 121   Step 27000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~99000.00UPS, TraCI: 20ms, vehicles TOT 23180 ACT 99 BU  Step 28000 — Target network updated
# Step #4500  Step 29000 — Target network updatedhicles TOT 30219 ACT 78 BUF 973)           00.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 26813 ACT 82 BUF 1323)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 33520 ACT 83 BUF 798)             Step 30000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 36670 ACT 66 BUF 784)             Step 31000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 39348 ACT 62 BUF 1228)            Step 32000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 41798 ACT 69 BUF 1906)            Step 33000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 44354 ACT 68 BUF 2472)            Step 34000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~80000.00UPS, TraCI: 15ms, vehicles TOT 47094 ACT 80 BU  Step 35000 — Target network updated
# Step #76500.00 (1ms ~= 1000.00*RT, ~84000.00UPS, TraCI: 16ms, vehicles TOT 49914 ACT 84 BU  Step 36000 — Target network updated
# Step #81000.00 (1ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 53248 ACT 85 BUF 2956)            Step 37000 — Target network updated
# Step #85500.00 (1ms ~= 1000.00*RT, ~84000.00UPS, TraCI: 16ms, vehicles TOT 56589 ACT 84 BU  Step 38000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~89000.00UPS, TraCI: 18ms, vehicles TOT 63092 ACT 89 BU?*RT. ?UPS, TraCI: 17ms, vehicles TOT 60000 ACT 89 BUF 2528)            Step 39000 — Target network updated
# Step #99000.00 (0ms ?* 1000.00*RT, ~76000.00UPS, TraCI: 15ms, vehicles TOT 66240 ACT 76 BU  Step 40000 — Target network updated
#   Episode   2 | Steps:  40000 | Epsilon: 0.099 | Waiting: 362.0s | Buffer: 40000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 66974 ACT 67 BUF 2498)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 2918 ACT 67 BUF 144)               Step 41000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 5798 ACT 66 BUF 390)               Step 42000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 8941 ACT 73 BUF 371)              Step 43000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 11895 ACT 73 BUF 543)             Step 44000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 14683 ACT 62 BUF 879)             Step 45000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~96000.00UPS, TraCI: 16ms, vehicles TOT 18053 ACT 96 BU  Step 46000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 21532 ACT 95 BUF 286)             Step 47000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 24938 ACT 60 BUF 4)               Step 48000 — Target network updated
# Step #4500  Step 49000 — Target network updatedicles TOT 31192 ACT 34 BUF 0)              00.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 28136 ACT 36 BUF 0)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 34318 ACT 35 BUF 0)                Step 50000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 37339 ACT 76 BUF 115)             Step 51000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~76000.00UPS, TraCI: 14ms, vehicles TOT 40309 ACT 76 BU  Step 52000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 43278 ACT 77 BUF 426)             Step 53000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 46380 ACT 78 BUF 446)             Step 54000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~82000.00UPS, TraCI: 16ms, vehicles TOT 49559 ACT 82 BU  Step 55000 — Target network updated
# Step #76500.00 (1ms ?*RT. ?UPS, TraCI: 20ms, vehicles TOT 52778 ACT 92 BUF 304)             Step 56000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 56204 ACT 40 BUF 0)                Step 57000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 59330 ACT 34 BUF 2)                Step 58000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 65579 ACT 42 BUF 3)              ~= 1000.00*RT, ~51000.00UPS, TraCI: 10ms, vehicles TOT 62527 ACT 51 BU  Step 59000 — Target network updated
# Step #99000.00 (1ms ~=RT. ?UPS, TraCI: 8ms, vehicles TOT 68703 ACT 34 BUF 1)                Step 60000 — Target network updated
#   Episode   3 | Steps:  60000 | Epsilon: 0.099 | Waiting: 173.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 69472 ACT 43 BUF 0)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 3062 ACT 56 BUF 0)                 Step 61000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 6188 ACT 47 BUF 0)                  Step 62000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 9311 ACT 51 BUF 1)                Step 63000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 12438 ACT 41 BUF 0)                Step 64000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 15561 ACT 58 BUF 1)               Step 65000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 18692 ACT 30 BUF 0)                Step 66000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 21818 ACT 32 BUF 0)                Step 67000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 24942 ACT 43 BUF 0)                Step 68000 — Target network updated
# Step #4500  Step 69000 — Target network updatedicles TOT 31191 ACT 42 BUF 1)              00.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 28136 ACT 37 BUF 0)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 34318 ACT 39 BUF 0)                Step 70000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 37448 ACT 65 BUF 6)               Step 71000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~66000.00UPS, TraCI: 12ms, vehicles TOT 40542 ACT 66 BU  Step 72000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 43704 ACT 48 BUF 0)               Step 73000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 46826 ACT 49 BUF 0)               Step 74000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 49954 ACT 47 BUF 0)                Step 75000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 53082 ACT 36 BUF 0)                Step 76000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 56204 ACT 40 BUF 0)               Step 77000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 59330 ACT 32 BUF 2)                Step 78000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 65580 ACT 36 BUF 2)              ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 62528 ACT 47 BUF 0)               Step 79000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 68704 ACT 37 BUF 0)                Step 80000 — Target network updated
#   Episode   4 | Steps:  80000 | Epsilon: 0.098 | Waiting: 329.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 69472 ACT 61 BUF 0)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 3062 ACT 60 BUF 0)                 Step 81000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 6188 ACT 57 BUF 0)                 Step 82000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 9312 ACT 43 BUF 0)                Step 83000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 12437 ACT 60 BUF 1)               Step 84000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 15560 ACT 53 BUF 2)               Step 85000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 18692 ACT 34 BUF 0)                Step 86000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 21818 ACT 46 BUF 0)               Step 87000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 24942 ACT 27 BUF 0)                Step 88000 — Target network updated
# Step #4500  Step 89000 — Target network updatedicles TOT 31192 ACT 41 BUF 0)              00.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 28136 ACT 38 BUF 0)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 34318 ACT 32 BUF 0)                Step 90000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 37452 ACT 66 BUF 2)               Step 91000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 40569 ACT 65 BUF 7)               Step 92000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 43674 ACT 64 BUF 30)              Step 93000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 46822 ACT 56 BUF 4)               Step 94000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~61000.00UPS, TraCI: 12ms, vehicles TOT 49954 ACT 61 BU  Step 95000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 53082 ACT 42 BUF 0)                Step 96000 — Target network updated
# Step #81000.00 (1ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 56204 ACT 27 BUF 0)                Step 97000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 59330 ACT 39 BUF 2)                Step 98000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 6ms, vehicles TOT 65580 ACT 33 BUF 2)              ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 62528 ACT 33 BUF 0)                Step 99000 — Target network updated
# Step #99000.00 (1ms ~=RT. ?UPS, TraCI: 7ms, vehicles TOT 68704 ACT 33 BUF 0)                Step 100000 — Target network updated
#   Episode   5 | Steps: 100000 | Epsilon: 0.098 | Waiting: 249.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 69472 ACT 41 BUF 0)
#  Retrying in 1 seconds
#
# Seed 42 complete. Model saved.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 0 ACT 0 BUF 0)
#
# ========================================
# Training Vanilla DQN v2 — Seed: 123
# ========================================
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 0 ACT 0 BUF 0)
# State dim: 21 | Action dim: 4
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 19ms, vehicles TOT 2339 ACT 87 BUF 723)               Step 1000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~82000.00UPS, TraCI: 16ms, vehicles TOT 5195 ACT 82 BUF   Step 2000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~80000.00UPS, TraCI: 17ms, vehicles TOT 7421 ACT 80 BUF  Step 3000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~93000.00UPS, TraCI: 19ms, vehicles TOT 9944 ACT 93 BUF  Step 4000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~52000.00UPS, TraCI: 12ms, vehicles TOT 12762 ACT 52 BU  Step 5000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~82000.00UPS, TraCI: 16ms, vehicles TOT 15315 ACT 82 BU  Step 6000 — Target network updated
# Step #31400.00 (2ms ~= 500.00*RT, ~45000.00UPS, TraCI: 18ms, vehicles TOT 18371 ACT 90 BUF  Step 7000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~102000.00UPS, TraCI: 21ms, vehicles TOT 21745 ACT 102   Step 8000 — Target network updated
# Step #4500  Step 9000 — Target network updatedS, TraCI: 16ms, vehicles TOT 28649 ACT 78 BU00.00 (2ms ~= 500.00*RT, ~55500.00UPS, TraCI: 23ms, vehicles TOT 25274 ACT 111 BU
# Step #49500.00 (2ms ~= 500.00*RT, ~35500.00UPS, TraCI: 18ms, vehicles TOT 31333 ACT 71 BUF  Step 10000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~59000.00UPS, TraCI: 23ms, vehicles TOT 34298 ACT 118 BU  Step 11000 — Target network updated
# Step #58500.00 (2ms ~= 500.00*RT, ~58500.00UPS, TraCI: 23ms, vehicles TOT 37521 ACT 117 BU  Step 12000 — Target network updated
# Step #63000.00 (2ms ~= 500.00*RT, ~59000.00UPS, TraCI: 21ms, vehicles TOT 40846 ACT 118 BU  Step 13000 — Target network updated
# Step #67500.00 (2ms ~= 500.00*RT, ~46500.00UPS, TraCI: 18ms, vehicles TOT 44225 ACT 93 BUF  Step 14000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~90000.00UPS, TraCI: 16ms, vehicles TOT 47715 ACT 90 BU  Step 15000 — Target network updated
# Step #76500.00 (2ms ~= 500.00*RT, ~43500.00UPS, TraCI: 18ms, vehicles TOT 51238 ACT 87 BUF  Step 16000 — Target network updated
# Step #81000.00 (1ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 54613 ACT 96 BUF 1591)            Step 17000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 57836 ACT 63 BUF 1496)            Step 18000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~79000.00UPS, TraCI: 15ms, vehicles TOT 64234 ACT 79 BU~= 1000.00*RT, ~68000.00UPS, TraCI: 13ms, vehicles TOT 61142 ACT 68 BU  Step 19000 — Target network updated
# Step #99000.00 (1ms ~= 1000.00*RT, ~61000.00UPS, TraCI: 13ms, vehicles TOT 67239 ACT 61 BU  Step 20000 — Target network updated
#   Episode   1 | Steps:  20000 | Epsilon: 0.100 | Waiting: 802.0s | Buffer: 20000
# Step #100000.00 (1ms ~= 1000.00*RT, ~68000.00UPS, TraCI: 14ms, vehicles TOT 67986 ACT 68 BU
#  Retrying in 1 seconds
# Step #4400.00 (1ms ~= 1000.00*RT, ~75000.00UPS, TraCI: 13ms, vehicles TOT 2815 ACT 75 BUF   Step 21000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 6179 ACT 57 BUF 9)                 Step 22000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 9307 ACT 63 BUF 5)                Step 23000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 12436 ACT 48 BUF 2)               Step 24000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 15560 ACT 55 BUF 2)               Step 25000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 18692 ACT 56 BUF 0)               Step 26000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 21818 ACT 47 BUF 0)               Step 27000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 24942 ACT 58 BUF 0)               Step 28000 — Target network updated
# Step #4500  Step 29000 — Target network updated, TraCI: 12ms, vehicles TOT 31127 ACT 60 BU00.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 28134 ACT 63 BUF 2)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 34251 ACT 65 BUF 67)              Step 30000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 37444 ACT 61 BUF 10)              Step 31000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~62000.00UPS, TraCI: 11ms, vehicles TOT 40559 ACT 62 BU  Step 32000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 43609 ACT 65 BUF 95)              Step 33000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 46802 ACT 55 BUF 24)              Step 34000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~68000.00UPS, TraCI: 14ms, vehicles TOT 49808 ACT 68 BU  Step 35000 — Target network updated
# Step #76500.00 (1ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 52925 ACT 95 BUF 157)             Step 36000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 56196 ACT 54 BUF 8)               Step 37000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 59145 ACT 78 BUF 187)             Step 38000 — Target network updated
# Step #94500.00 (0ms ?= 1000.00*RT, ~80000.00UPS, TraCI: 15ms, vehicles TOT 65420 ACT 80 BU?*RT. ?UPS, TraCI: 12ms, vehicles TOT 62210 ACT 63 BUF 318)             Step 39000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 68274 ACT 82 BUF 430)             Step 40000 — Target network updated
#   Episode   2 | Steps:  40000 | Epsilon: 0.099 | Waiting: 3754.0s | Buffer: 40000
# Step #100000.00 (1ms ~= 1000.00*RT, ~82000.00UPS, TraCI: 16ms, vehicles TOT 69079 ACT 82 BU
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 2903 ACT 53 BUF 159)               Step 41000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 5858 ACT 67 BUF 330)               Step 42000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 9121 ACT 70 BUF 191)              Step 43000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 12184 ACT 64 BUF 254)             Step 44000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~62000.00UPS, TraCI: 12ms, vehicles TOT 15185 ACT 62 BU  Step 45000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 18421 ACT 87 BUF 271)             Step 46000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 19ms, vehicles TOT 21622 ACT 92 BUF 196)             Step 47000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 24848 ACT 85 BUF 94)              Step 48000 — Target network updated
# Step #4500  Step 49000 — Target network updatedhicles TOT 30369 ACT 77 BUF 823)           00.00 (1ms ~= 1000.00*RT, ~66000.00UPS, TraCI: 13ms, vehicles TOT 27552 ACT 66 BU
# Step #49500.00 (1ms ~= 1000.00*RT, ~72000.00UPS, TraCI: 13ms, vehicles TOT 33169 ACT 72 BU  Step 50000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 36497 ACT 100 BUF 957)            Step 51000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 39411 ACT 66 BUF 1165)            Step 52000 — Target network updated
# Step #63000.00 (1ms ~= 1000.00*RT, ~54000.00UPS, TraCI: 11ms, vehicles TOT 42138 ACT 54 BU  Step 53000 — Target network updated
# Step #67500.00 (1ms ~= 1000.00*RT, ~53000.00UPS, TraCI: 11ms, vehicles TOT 44852 ACT 53 BU  Step 54000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~54000.00UPS, TraCI: 11ms, vehicles TOT 47579 ACT 54 BU  Step 55000 — Target network updated
# Step #76500.00 (1ms ~= 500.00*RT, ~47000.00UPS, TraCI: 18ms, vehicles TOT 50602 ACT 94 BUF  Step 56000 — Target network updated
# Step #81000.00 (1ms ~= 1000.00*RT, ~90000.00UPS, TraCI: 18ms, vehicles TOT 53776 ACT 90 BU  Step 57000 — Target network updated
# Step #85500.00 (1ms ~= 500.00*RT, ~42000.00UPS, TraCI: 17ms, vehicles TOT 57001 ACT 84 BUF  Step 58000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~56000.00UPS, TraCI: 12ms, vehicles TOT 63424 ACT 56 BU~= 1000.00*RT, ~80000.00UPS, TraCI: 16ms, vehicles TOT 60270 ACT 80 BU  Step 59000 — Target network updated
# Step #99000.00 (1ms ~=RT. ?UPS, TraCI: 17ms, vehicles TOT 66751 ACT 81 BUF 1953)            Step 60000 — Target network updated
#   Episode   3 | Steps:  60000 | Epsilon: 0.099 | Waiting: 401.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 67594 ACT 78 BUF 1878)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 3015 ACT 56 BUF 47)                Step 61000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 6114 ACT 59 BUF 74)                Step 62000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 9057 ACT 54 BUF 255)              Step 63000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 11977 ACT 51 BUF 461)             Step 64000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 14903 ACT 57 BUF 659)             Step 65000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 18030 ACT 97 BUF 662)             Step 66000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 21182 ACT 62 BUF 636)             Step 67000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 24562 ACT 60 BUF 380)             Step 68000 — Target network updated
# Step #4500  Step 69000 — Target network updatedhicles TOT 31192 ACT 48 BUF 0)             00.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 28114 ACT 74 BUF 22)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 34318 ACT 50 BUF 0)               Step 70000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 37453 ACT 51 BUF 1)                Step 71000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~55000.00UPS, TraCI: 11ms, vehicles TOT 40562 ACT 55 BU  Step 72000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 43704 ACT 51 BUF 0)               Step 73000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 46826 ACT 43 BUF 0)                Step 74000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 49949 ACT 52 BUF 5)               Step 75000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 53082 ACT 54 BUF 0)               Step 76000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 56204 ACT 43 BUF 0)                Step 77000 — Target network updated
# Step #85500.00 (1ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 59330 ACT 38 BUF 2)                Step 78000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 65548 ACT 64 BUF 34)            ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 62528 ACT 36 BUF 0)                Step 79000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 68699 ACT 48 BUF 5)               Step 80000 — Target network updated
#   Episode   4 | Steps:  80000 | Epsilon: 0.098 | Waiting: 522.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 69461 ACT 58 BUF 11)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 3062 ACT 45 BUF 0)                  Step 81000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 6180 ACT 62 BUF 8)                 Step 82000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 9261 ACT 48 BUF 51)                Step 83000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 12341 ACT 62 BUF 97)              Step 84000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 15507 ACT 61 BUF 55)              Step 85000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 18689 ACT 64 BUF 3)               Step 86000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 21818 ACT 49 BUF 0)               Step 87000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 24933 ACT 54 BUF 9)               Step 88000 — Target network updated
# Step #4500  Step 89000 — Target network updatedhicles TOT 31186 ACT 53 BUF 6)             00.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 28136 ACT 67 BUF 0)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 34256 ACT 68 BUF 62)              Step 90000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 37454 ACT 50 BUF 0)               Step 91000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 40576 ACT 47 BUF 0)               Step 92000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 43699 ACT 50 BUF 5)               Step 93000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 46819 ACT 59 BUF 7)               Step 94000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 49939 ACT 50 BUF 15)              Step 95000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 53031 ACT 71 BUF 51)              Step 96000 — Target network updated
# Step #81000.00 (1ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 56148 ACT 71 BUF 56)              Step 97000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 59302 ACT 76 BUF 30)              Step 98000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 65261 ACT 66 BUF 321)           ~= 1000.00*RT, ~65000.00UPS, TraCI: 13ms, vehicles TOT 62364 ACT 65 BU  Step 99000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 68337 ACT 69 BUF 367)             Step 100000 — Target network updated
#   Episode   5 | Steps: 100000 | Epsilon: 0.098 | Waiting: 889.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 69136 ACT 77 BUF 336)
#  Retrying in 1 seconds
#
# Seed 123 complete. Model saved.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 0 ACT 0 BUF 0)
#
# ========================================
# Training Vanilla DQN v2 — Seed: 456
# ========================================
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 0 ACT 0 BUF 0)
# State dim: 21 | Action dim: 4
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 2497 ACT 83 BUF 565)               Step 1000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 4958 ACT 54 BUF 1230)              Step 2000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 7662 ACT 57 BUF 1650)             Step 3000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 10844 ACT 56 BUF 1594)            Step 4000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~56000.00UPS, TraCI: 11ms, vehicles TOT 13936 ACT 56 BU  Step 5000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~79000.00UPS, TraCI: 16ms, vehicles TOT 17053 ACT 79 BU  Step 6000 — Target network updated
# Step #31400.00 (1ms ~= 1000.00*RT, ~102000.00UPS, TraCI: 21ms, vehicles TOT 20357 ACT 102   Step 7000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~108000.00UPS, TraCI: 22ms, vehicles TOT 23295 ACT 108   Step 8000 — Target network updated
# Step #4500  Step 9000 — Target network updatedS, TraCI: 15ms, vehicles TOT 28106 ACT 73 BU00.00 (1ms ~= 1000.00*RT, ~92000.00UPS, TraCI: 19ms, vehicles TOT 25720 ACT 92 BU
# Step #49500.00 (1ms ~= 1000.00*RT, ~101000.00UPS, TraCI: 20ms, vehicles TOT 30805 ACT 101   Step 10000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~62500.00UPS, TraCI: 24ms, vehicles TOT 33922 ACT 125 BU  Step 11000 — Target network updated
# Step #58500.00 (2ms ~= 500.00*RT, ~60000.00UPS, TraCI: 23ms, vehicles TOT 37100 ACT 120 BU  Step 12000 — Target network updated
# Step #63000.00 (1ms ~= 1000.00*RT, ~119000.00UPS, TraCI: 23ms, vehicles TOT 40276 ACT 119   Step 13000 — Target network updated
# Step #67500.00 (1ms ~= 1000.00*RT, ~69000.00UPS, TraCI: 13ms, vehicles TOT 43479 ACT 69 BU  Step 14000 — Target network updated
# Step #72000.00 (2ms ~= 500.00*RT, ~25000.00UPS, TraCI: 11ms, vehicles TOT 46669 ACT 50 BUF  Step 15000 — Target network updated
# Step #76500.00 (2ms ~= 1000.00*RT, ~103000.00UPS, TraCI: 20ms, vehicles TOT 49622 ACT 103   Step 16000 — Target network updated
# Step #81000.00 (2ms ~= 500.00*RT, ~54500.00UPS, TraCI: 21ms, vehicles TOT 52504 ACT 109 BU  Step 17000 — Target network updated
# Step #85500.00 (2ms ~= 500.00*RT, ~50000.00UPS, TraCI: 19ms, vehicles TOT 55437 ACT 100 BU  Step 18000 — Target network updated
# Step #94500.00 (2ms ~= 500.00*RT, ~46000.00UPS, TraCI: 22ms, vehicles TOT 61951 ACT 92 BUF~= 500.00*RT, ~56000.00UPS, TraCI: 23ms, vehicles TOT 58723 ACT 112 BU  Step 19000 — Target network updated
# Step #99000.00 (1ms ~= 500.00*RT, ~49500.00UPS, TraCI: 19ms, vehicles TOT 65416 ACT 99 BUF  Step 20000 — Target network updated
#   Episode   1 | Steps:  20000 | Epsilon: 0.100 | Waiting: 91.0s | Buffer: 20000
# Step #100000.00 (1ms ~= 1000.00*RT, ~53000.00UPS, TraCI: 14ms, vehicles TOT 66142 ACT 53 BU
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 2987 ACT 73 BUF 75)                Step 21000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~72000.00UPS, TraCI: 15ms, vehicles TOT 6175 ACT 72 BUF   Step 22000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~91000.00UPS, TraCI: 18ms, vehicles TOT 9081 ACT 91 BUF  Step 23000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~77000.00UPS, TraCI: 15ms, vehicles TOT 11933 ACT 77 BU  Step 24000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 14880 ACT 79 BUF 682)             Step 25000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~49000.00UPS, TraCI: 11ms, vehicles TOT 18183 ACT 49 BU  Step 26000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 21458 ACT 64 BUF 360)             Step 27000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 24279 ACT 51 BUF 663)             Step 28000 — Target network updated
# Step #4500  Step 29000 — Target network updated TraCI: 11ms, vehicles TOT 28622 ACT 47 BUF00.00 (1ms ~= 1000.00*RT, ~44000.00UPS, TraCI: 9ms, vehicles TOT 26716 ACT 44 BUF
# Step #49500.00 (2ms ~= 500.00*RT, ~24000.00UPS, TraCI: 12ms, vehicles TOT 30350 ACT 48 BUF  Step 30000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~40000.00UPS, TraCI: 17ms, vehicles TOT 33203 ACT 80 BUF  Step 31000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~91000.00UPS, TraCI: 18ms, vehicles TOT 36530 ACT 91 BU  Step 32000 — Target network updated
# Step #63000.00 (2ms ~= 500.00*RT, ~52000.00UPS, TraCI: 21ms, vehicles TOT 40037 ACT 104 BU  Step 33000 — Target network updated
# Step #67500.00 (2ms ~= 500.00*RT, ~66000.00UPS, TraCI: 24ms, vehicles TOT 43525 ACT 132 BU  Step 34000 — Target network updated
# Step #72000.00 (2ms ~= 500.00*RT, ~53500.00UPS, TraCI: 22ms, vehicles TOT 47122 ACT 107 BU  Step 35000 — Target network updated
# Step #76500.00 (1ms ~= 500.00*RT, ~30000.00UPS, TraCI: 15ms, vehicles TOT 50408 ACT 60 BUF  Step 36000 — Target network updated
# Step #81000.00 (1ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 53499 ACT 58 BUF 2705)            Step 37000 — Target network updated
# Step #85500.00 (1ms ~= 1000.00*RT, ~50000.00UPS, TraCI: 11ms, vehicles TOT 56537 ACT 50 BU  Step 38000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~81000.00UPS, TraCI: 16ms, vehicles TOT 63857 ACT 81 BU~= 1000.00*RT, ~84000.00UPS, TraCI: 22ms, vehicles TOT 60271 ACT 84 BU  Step 39000 — Target network updated
# Step #99000.00 (1ms ~= 1000.00*RT, ~89000.00UPS, TraCI: 16ms, vehicles TOT 67496 ACT 89 BU  Step 40000 — Target network updated
#   Episode   2 | Steps:  40000 | Epsilon: 0.099 | Waiting: 2940.0s | Buffer: 40000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 68377 ACT 75 BUF 1095)
#  Retrying in 1 seconds
# Step #4400.00 (1ms ~= 1000.00*RT, ~84000.00UPS, TraCI: 16ms, vehicles TOT 3040 ACT 84 BUF   Step 41000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 6186 ACT 83 BUF 2)                 Step 42000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 9312 ACT 51 BUF 0)                Step 43000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 12438 ACT 52 BUF 0)               Step 44000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 15562 ACT 46 BUF 0)                Step 45000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~68000.00UPS, TraCI: 15ms, vehicles TOT 18475 ACT 68 BU  Step 46000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 21267 ACT 58 BUF 551)             Step 47000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~76000.00UPS, TraCI: 15ms, vehicles TOT 24299 ACT 76 BU  Step 48000 — Target network updated
# Step #4500  Step 49000 — Target network updatedhicles TOT 30566 ACT 77 BUF 626)           00.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 27453 ACT 67 BUF 683)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 33894 ACT 70 BUF 424)             Step 50000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 37245 ACT 75 BUF 209)             Step 51000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 40576 ACT 37 BUF 0)                Step 52000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 43704 ACT 45 BUF 0)                Step 53000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 46826 ACT 38 BUF 0)                Step 54000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 49954 ACT 39 BUF 0)                Step 55000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 53082 ACT 57 BUF 0)               Step 56000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 56198 ACT 56 BUF 6)               Step 57000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 59322 ACT 62 BUF 10)              Step 58000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~74000.00UPS, TraCI: 15ms, vehicles TOT 64943 ACT 74 BU~= 1000.00*RT, ~53000.00UPS, TraCI: 16ms, vehicles TOT 62002 ACT 53 BU  Step 59000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 68223 ACT 65 BUF 481)             Step 60000 — Target network updated
#   Episode   3 | Steps:  60000 | Epsilon: 0.099 | Waiting: 717.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 69077 ACT 75 BUF 395)
#  Retrying in 1 seconds
# Step #4400.00 (1ms ~= 1000.00*RT, ~51000.00UPS, TraCI: 15ms, vehicles TOT 3062 ACT 51 BUF   Step 61000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 6188 ACT 45 BUF 0)                 Step 62000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 9312 ACT 41 BUF 0)                 Step 63000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 12438 ACT 40 BUF 0)                Step 64000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 15562 ACT 44 BUF 0)               Step 65000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 18679 ACT 70 BUF 13)              Step 66000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 21225 ACT 45 BUF 593)             Step 67000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~78000.00UPS, TraCI: 18ms, vehicles TOT 24461 ACT 78 BU  Step 68000 — Target network updated
# Step #4500  Step 69000 — Target network updatedhicles TOT 31165 ACT 81 BUF 27)            00.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 28003 ACT 82 BUF 133)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 34305 ACT 73 BUF 13)              Step 70000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 37454 ACT 42 BUF 0)                Step 71000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~40000.00UPS, TraCI: 8ms, vehicles TOT 40576 ACT 40 BUF  Step 72000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 43704 ACT 44 BUF 0)                Step 73000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 46826 ACT 34 BUF 0)                Step 74000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 49954 ACT 40 BUF 0)               Step 75000 — Target network updated
# Step #76500.00 (0ms ~= 1000.00*RT, ~47000.00UPS, TraCI: 10ms, vehicles TOT 52860 ACT 47 BU  Step 76000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 55143 ACT 43 BUF 1061)            Step 77000 — Target network updated
# Step #85500.00 (1ms ~= 1000.00*RT, ~49000.00UPS, TraCI: 10ms, vehicles TOT 57475 ACT 49 BU  Step 78000 — Target network updated
# Step #94500.00 (3ms ~= 500.00*RT, ~23500.00UPS, TraCI: 11ms, vehicles TOT 62093 ACT 47 BUF~= 1000.00*RT, ~50000.00UPS, TraCI: 10ms, vehicles TOT 59911 ACT 50 BU  Step 79000 — Target network updated
# Step #99000.00 (1ms ~= 1000.00*RT, ~46000.00UPS, TraCI: 12ms, vehicles TOT 64317 ACT 46 BU  Step 80000 — Target network updated
#   Episode   4 | Steps:  80000 | Epsilon: 0.098 | Waiting: 432.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 64835 ACT 51 BUF 4637)
#  Retrying in 1 seconds
# Step #4400.00 (1ms ~= 1000.00*RT, ~59000.00UPS, TraCI: 12ms, vehicles TOT 2980 ACT 59 BUF   Step 81000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 6176 ACT 62 BUF 12)                Step 82000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 9129 ACT 70 BUF 183)              Step 83000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~50000.00UPS, TraCI: 12ms, vehicles TOT 12438 ACT 50 BU  Step 84000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~41000.00UPS, TraCI: 10ms, vehicles TOT 15562 ACT 41 BU  Step 85000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 18692 ACT 54 BUF 0)               Step 86000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 21818 ACT 51 BUF 0)               Step 87000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 24941 ACT 52 BUF 1)               Step 88000 — Target network updated
# Step #4500  Step 89000 — Target network updatedhicles TOT 31163 ACT 68 BUF 29)            00.00 (1ms ~= 1000.00*RT, ~61000.00UPS, TraCI: 13ms, vehicles TOT 28136 ACT 61 BU
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 34296 ACT 70 BUF 22)              Step 90000 — Target network updated
# Step #54000.00 (1ms ~= 1000.00*RT, ~42000.00UPS, TraCI: 9ms, vehicles TOT 37454 ACT 42 BUF  Step 91000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 40576 ACT 54 BUF 0)               Step 92000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 43704 ACT 63 BUF 0)               Step 93000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 46826 ACT 56 BUF 0)               Step 94000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 49954 ACT 55 BUF 0)               Step 95000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 53081 ACT 60 BUF 1)               Step 96000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 56164 ACT 65 BUF 40)              Step 97000 — Target network updated
# Step #85500.00 (0ms ~= 1000.00*RT, ~77000.00UPS, TraCI: 14ms, vehicles TOT 58974 ACT 77 BU  Step 98000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 65331 ACT 78 BUF 251)           ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 62234 ACT 79 BUF 294)             Step 99000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 68533 ACT 78 BUF 171)             Step 100000 — Target network updated
#   Episode   5 | Steps: 100000 | Epsilon: 0.098 | Waiting: 655.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 69307 ACT 80 BUF 165)
#  Retrying in 1 seconds
#
# Seed 456 complete. Model saved.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 0 ACT 0 BUF 0)
#
# ========================================
# Training Vanilla DQN v2 — Seed: 789
# ========================================
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 1ms, vehicles TOT 0 ACT 0 BUF 0)
# State dim: 21 | Action dim: 4
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 2232 ACT 56 BUF 830)               Step 1000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~82000.00UPS, TraCI: 17ms, vehicles TOT 4836 ACT 82 BUF   Step 2000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 19ms, vehicles TOT 7636 ACT 94 BUF 1676)             Step 3000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~57000.00UPS, TraCI: 12ms, vehicles TOT 9379 ACT 57 BUF  Step 4000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~54000.00UPS, TraCI: 12ms, vehicles TOT 11134 ACT 54 BU  Step 5000 — Target network updated
# Step #26900.00 (2ms ~= 500.00*RT, ~42000.00UPS, TraCI: 18ms, vehicles TOT 13869 ACT 84 BUF  Step 6000 — Target network updated
# Step #31400.00 (3ms ~= 333.33*RT, ~33000.00UPS, TraCI: 20ms, vehicles TOT 17130 ACT 99 BUF  Step 7000 — Target network updated
# Step #36900.00 (3ms ~= 333.33*RT, ~38666.67UPS, TraCI: 25ms, vehicles TOT 20484 ACT 116 BU  Step 8000 — Target network updated
# Step #4500  Step 9000 — Target network updated, TraCI: 21ms, vehicles TOT 26449 ACT 108 BU00.00 (2ms ~= 500.00*RT, ~55000.00UPS, TraCI: 23ms, vehicles TOT 23708 ACT 110 BU
# Step #49500.00 (3ms ~= 333.33*RT, ~35333.33UPS, TraCI: 20ms, vehicles TOT 29483 ACT 106 BU  Step 10000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~56000.00UPS, TraCI: 21ms, vehicles TOT 32441 ACT 112 BU  Step 11000 — Target network updated
# Step #58500.00 (3ms ~= 333.33*RT, ~30333.33UPS, TraCI: 18ms, vehicles TOT 35493 ACT 91 BUF  Step 12000 — Target network updated
# Step #63000.00 (2ms ~= 500.00*RT, ~55000.00UPS, TraCI: 22ms, vehicles TOT 38703 ACT 110 BU  Step 13000 — Target network updated
# Step #67500.00 (3ms ~= 333.33*RT, ~30333.33UPS, TraCI: 18ms, vehicles TOT 42000 ACT 91 BUF  Step 14000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~67000.00UPS, TraCI: 14ms, vehicles TOT 45398 ACT 67 BU  Step 15000 — Target network updated
# Step #76500.00 (5ms ~= 333.33*RT, ~31333.33UPS, TraCI: 19ms, vehicles TOT 48741 ACT 94 BUF  Step 16000 — Target network updated
# Step #81000.00 (2ms ~= 500.00*RT, ~45500.00UPS, TraCI: 18ms, vehicles TOT 52058 ACT 91 BUF  Step 17000 — Target network updated
# Step #85500.00 (2ms ~= 500.00*RT, ~47000.00UPS, TraCI: 18ms, vehicles TOT 55413 ACT 94 BUF  Step 18000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~80000.00UPS, TraCI: 16ms, vehicles TOT 62249 ACT 80 BU~= 500.00*RT, ~52000.00UPS, TraCI: 20ms, vehicles TOT 58940 ACT 104 BU  Step 19000 — Target network updated
# Step #99000.00 (1ms ~= 1000.00*RT, ~91000.00UPS, TraCI: 18ms, vehicles TOT 65558 ACT 91 BU  Step 20000 — Target network updated
#   Episode   1 | Steps:  20000 | Epsilon: 0.100 | Waiting: 903.0s | Buffer: 20000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 18ms, vehicles TOT 66379 ACT 95 BUF 3093)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 2127 ACT 51 BUF 935)               Step 21000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~50000.00UPS, TraCI: 10ms, vehicles TOT 4365 ACT 50 BUF   Step 22000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~52000.00UPS, TraCI: 11ms, vehicles TOT 6658 ACT 52 BUF  Step 23000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~54000.00UPS, TraCI: 12ms, vehicles TOT 8894 ACT 54 BUF  Step 24000 — Target network updated
# ...
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 53081 ACT 43 BUF 1)               Step 96000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 56202 ACT 55 BUF 2)               Step 97000 — Target network updated
# Step #85500.00 (1ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 59330 ACT 40 BUF 2)                Step 98000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 65580 ACT 59 BUF 2)             ~= 1000.00*RT, ~52000.00UPS, TraCI: 10ms, vehicles TOT 62528 ACT 52 BU  Step 99000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 68704 ACT 44 BUF 0)                Step 100000 — Target network updated
#   Episode   5 | Steps: 100000 | Epsilon: 0.098 | Waiting: 463.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 69472 ACT 49 BUF 0)
#  Retrying in 1 seconds
#
# Seed 789 complete. Model saved.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 0 ACT 0 BUF 0)
#
# ========================================
# Training Vanilla DQN v2 — Seed: 1000
# ========================================
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 0 ACT 0 BUF 0)
# State dim: 21 | Action dim: 4
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 2611 ACT 67 BUF 451)               Step 1000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~73000.00UPS, TraCI: 14ms, vehicles TOT 5057 ACT 73 BUF   Step 2000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~54000.00UPS, TraCI: 11ms, vehicles TOT 7757 ACT 54 BUF  Step 3000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 10398 ACT 57 BUF 2040)            Step 4000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~60000.00UPS, TraCI: 13ms, vehicles TOT 13211 ACT 60 BU  Step 5000 — Target network updated
# Step #26900.00 (1ms ~= 1000.00*RT, ~80000.00UPS, TraCI: 16ms, vehicles TOT 16076 ACT 80 BU  Step 6000 — Target network updated
# Step #31400.00 (1ms ~= 1000.00*RT, ~86000.00UPS, TraCI: 17ms, vehicles TOT 18957 ACT 86 BU  Step 7000 — Target network updated
# Step #36900.00 (1ms ~= 1000.00*RT, ~88000.00UPS, TraCI: 19ms, vehicles TOT 21909 ACT 88 BU  Step 8000 — Target network updated
# Step #4500  Step 9000 — Target network updated, TraCI: 11ms, vehicles TOT 26651 ACT 51 BUF00.00 (1ms ~= 1000.00*RT, ~43000.00UPS, TraCI: 12ms, vehicles TOT 24435 ACT 43 BU
# Step #49500.00 (1ms ~= 1000.00*RT, ~45000.00UPS, TraCI: 11ms, vehicles TOT 29030 ACT 45 BU  Step 10000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~39000.00UPS, TraCI: 16ms, vehicles TOT 31962 ACT 78 BUF  Step 11000 — Target network updated
# Step #58500.00 (2ms ~= 500.00*RT, ~43500.00UPS, TraCI: 18ms, vehicles TOT 35095 ACT 87 BUF  Step 12000 — Target network updated
# Step #63000.00 (2ms ~= 500.00*RT, ~39000.00UPS, TraCI: 16ms, vehicles TOT 38315 ACT 78 BUF  Step 13000 — Target network updated
# Step #67500.00 (2ms ~= 500.00*RT, ~43500.00UPS, TraCI: 17ms, vehicles TOT 41662 ACT 87 BUF  Step 14000 — Target network updated
# Step #72000.00 (3ms ~= 333.33*RT, ~28666.67UPS, TraCI: 18ms, vehicles TOT 45044 ACT 86 BUF  Step 15000 — Target network updated
# Step #76500.00 (2ms ~= 500.00*RT, ~44000.00UPS, TraCI: 16ms, vehicles TOT 48288 ACT 88 BUF  Step 16000 — Target network updated
# Step #81000.00 (2ms ~= 500.00*RT, ~42000.00UPS, TraCI: 18ms, vehicles TOT 51441 ACT 84 BUF  Step 17000 — Target network updated
# Step #85500.00 (2ms ~= 500.00*RT, ~27500.00UPS, TraCI: 13ms, vehicles TOT 54219 ACT 55 BUF  Step 18000 — Target network updated
# Step #94500.00 (2ms ~= 500.00*RT, ~29000.00UPS, TraCI: 12ms, vehicles TOT 59770 ACT 58 BUF~= 500.00*RT, ~27000.00UPS, TraCI: 12ms, vehicles TOT 57015 ACT 54 BUF  Step 19000 — Target network updated
# Step #99000.00 (3ms ~= 333.33*RT, ~18000.00UPS, TraCI: 13ms, vehicles TOT 62397 ACT 54 BUF  Step 20000 — Target network updated
#   Episode   1 | Steps:  20000 | Epsilon: 0.100 | Waiting: 471.0s | Buffer: 20000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 63079 ACT 63 BUF 6393)
#  Retrying in 1 seconds
# Step #4400.00 (1ms ~= 1000.00*RT, ~53000.00UPS, TraCI: 10ms, vehicles TOT 3062 ACT 53 BUF   Step 21000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 6188 ACT 45 BUF 0)                 Step 22000 — Target network updated
# Step #13400.00 (1ms ~= 1000.00*RT, ~72000.00UPS, TraCI: 14ms, vehicles TOT 9249 ACT 72 BUF  Step 23000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 12220 ACT 71 BUF 218)             Step 24000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 15558 ACT 65 BUF 4)               Step 25000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 18481 ACT 72 BUF 211)             Step 26000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 21090 ACT 76 BUF 728)             Step 27000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 17ms, vehicles TOT 23674 ACT 82 BUF 1268)            Step 28000 — Target network updated
# Step #4500  Step 29000 — Target network updated, TraCI: 15ms, vehicles TOT 29119 ACT 77 BU00.00 (0ms ?*RT. ?UPS, TraCI: 16ms, vehicles TOT 26496 ACT 78 BUF 1640)
# Step #49500.00 (1ms ~= 1000.00*RT, ~80000.00UPS, TraCI: 16ms, vehicles TOT 31966 ACT 80 BU  Step 30000 — Target network updated
# Step #54000.00 (2ms ~= 500.00*RT, ~69500.00UPS, TraCI: 25ms, vehicles TOT 35162 ACT 139 BU  Step 31000 — Target network updated
# Step #58500.00 (2ms ~= 500.00*RT, ~60500.00UPS, TraCI: 25ms, vehicles TOT 38348 ACT 121 BU  Step 32000 — Target network updated
# Step #63000.00 (2ms ~= 500.00*RT, ~30500.00UPS, TraCI: 12ms, vehicles TOT 41390 ACT 61 BUF  Step 33000 — Target network updated
# Step #67500.00 (1ms ~= 1000.00*RT, ~74000.00UPS, TraCI: 15ms, vehicles TOT 44509 ACT 74 BU  Step 34000 — Target network updated
# Step #72000.00 (1ms ~= 1000.00*RT, ~64000.00UPS, TraCI: 12ms, vehicles TOT 47969 ACT 64 BU  Step 35000 — Target network updated
# Step #76500.00 (1ms ~= 1000.00*RT, ~101000.00UPS, TraCI: 20ms, vehicles TOT 51355 ACT 101   Step 36000 — Target network updated
# Step #81000.00 (2ms ~= 1000.00*RT, ~93000.00UPS, TraCI: 18ms, vehicles TOT 54697 ACT 93 BU  Step 37000 — Target network updated
# Step #85500.00 (1ms ~= 1000.00*RT, ~85000.00UPS, TraCI: 17ms, vehicles TOT 58035 ACT 85 BU  Step 38000 — Target network updated
# Step #94500.00 (1ms ~= 1000.00*RT, ~59000.00UPS, TraCI: 12ms, vehicles TOT 63799 ACT 59 BU~= 1000.00*RT, ~65000.00UPS, TraCI: 13ms, vehicles TOT 61098 ACT 65 BU  Step 39000 — Target network updated
# Step #99000.00 (1ms ~= 1000.00*RT, ~55000.00UPS, TraCI: 13ms, vehicles TOT 66624 ACT 55 BU  Step 40000 — Target network updated
#   Episode   2 | Steps:  40000 | Epsilon: 0.099 | Waiting: 634.0s | Buffer: 40000
# Step #100000.00 (1ms ~= 1000.00*RT, ~65000.00UPS, TraCI: 14ms, vehicles TOT 67349 ACT 65 BU
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 2929 ACT 54 BUF 133)               Step 41000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~59000.00UPS, TraCI: 12ms, vehicles TOT 6058 ACT 59 BUF   Step 42000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 9145 ACT 56 BUF 167)              Step 43000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 12390 ACT 59 BUF 48)              Step 44000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 15562 ACT 58 BUF 0)               Step 45000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 18533 ACT 54 BUF 159)             Step 46000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 21410 ACT 50 BUF 408)             Step 47000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 24144 ACT 56 BUF 798)             Step 48000 — Target network updated
# Step #4500  Step 49000 — Target network updated, TraCI: 12ms, vehicles TOT 29574 ACT 56 BU00.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 26799 ACT 51 BUF 1337)
# Step #49500.00 (1ms ~= 1000.00*RT, ~57000.00UPS, TraCI: 11ms, vehicles TOT 32445 ACT 57 BU  Step 50000 — Target network updated
# Step #54000.00 (1ms ~= 1000.00*RT, ~91000.00UPS, TraCI: 18ms, vehicles TOT 35685 ACT 91 BU  Step 51000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~93000.00UPS, TraCI: 17ms, vehicles TOT 39030 ACT 93 BU  Step 52000 — Target network updated
# Step #63000.00 (1ms ~= 1000.00*RT, ~64000.00UPS, TraCI: 15ms, vehicles TOT 42369 ACT 64 BU  Step 53000 — Target network updated
# Step #67500.00 (1ms ~= 1000.00*RT, ~75000.00UPS, TraCI: 16ms, vehicles TOT 45992 ACT 75 BU  Step 54000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 49497 ACT 60 BUF 457)             Step 55000 — Target network updated
# Step #76500.00 (1ms ?*RT. ?UPS, TraCI: 19ms, vehicles TOT 52958 ACT 96 BUF 124)             Step 56000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 55979 ACT 64 BUF 225)             Step 57000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 58987 ACT 63 BUF 345)             Step 58000 — Target network updated
# Step #94500.00 (0ms ?= 1000.00*RT, ~70000.00UPS, TraCI: 14ms, vehicles TOT 65322 ACT 70 BU?*RT. ?UPS, TraCI: 15ms, vehicles TOT 62126 ACT 61 BUF 402)             Step 59000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 68686 ACT 70 BUF 18)              Step 60000 — Target network updated
#   Episode   3 | Steps:  60000 | Epsilon: 0.099 | Waiting: 194.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 69469 ACT 68 BUF 3)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 3062 ACT 54 BUF 0)                 Step 61000 — Target network updated
# Step #8900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 6186 ACT 55 BUF 2)                 Step 62000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 9312 ACT 36 BUF 0)                 Step 63000 — Target network updated
# Step #17900.00 (1ms ~= 1000.00*RT, ~46000.00UPS, TraCI: 10ms, vehicles TOT 12438 ACT 46 BU  Step 64000 — Target network updated
# Step #22400.00 (1ms ~= 1000.00*RT, ~32000.00UPS, TraCI: 7ms, vehicles TOT 15562 ACT 32 BUF  Step 65000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 18692 ACT 45 BUF 0)                Step 66000 — Target network updated
# Step #31400.00 (1ms ~= 1000.00*RT, ~46000.00UPS, TraCI: 10ms, vehicles TOT 21818 ACT 46 BU  Step 67000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 24942 ACT 53 BUF 0)               Step 68000 — Target network updated
# Step #4500  Step 69000 — Target network updatedhicles TOT 31192 ACT 50 BUF 0)             00.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 28136 ACT 52 BUF 0)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 34318 ACT 53 BUF 0)               Step 70000 — Target network updated
# Step #54000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 37454 ACT 58 BUF 0)               Step 71000 — Target network updated
# Step #58500.00 (1ms ~= 1000.00*RT, ~39000.00UPS, TraCI: 9ms, vehicles TOT 40576 ACT 39 BUF  Step 72000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 43699 ACT 51 BUF 5)               Step 73000 — Target network updated
# Step #67500.00 (1ms ~= 1000.00*RT, ~59000.00UPS, TraCI: 11ms, vehicles TOT 46804 ACT 59 BU  Step 74000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 49954 ACT 56 BUF 0)               Step 75000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 53082 ACT 38 BUF 0)                Step 76000 — Target network updated
# Step #81000.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 56203 ACT 64 BUF 1)               Step 77000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 59330 ACT 53 BUF 2)               Step 78000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 65573 ACT 59 BUF 9)             ~= 1000.00*RT, ~60000.00UPS, TraCI: 12ms, vehicles TOT 62523 ACT 60 BU  Step 79000 — Target network updated
# Step #99000.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 68692 ACT 65 BUF 12)              Step 80000 — Target network updated
#   Episode   4 | Steps:  80000 | Epsilon: 0.098 | Waiting: 383.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 69468 ACT 69 BUF 4)
#  Retrying in 1 seconds
# Step #4400.00 (0ms ?*RT. ?UPS, TraCI: 14ms, vehicles TOT 3062 ACT 50 BUF 0)                 Step 81000 — Target network updated
# Step #8900.00 (1ms ~= 1000.00*RT, ~37000.00UPS, TraCI: 9ms, vehicles TOT 6188 ACT 37 BUF 0  Step 82000 — Target network updated
# Step #13400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 9312 ACT 40 BUF 0)                 Step 83000 — Target network updated
# Step #17900.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 12438 ACT 55 BUF 0)               Step 84000 — Target network updated
# Step #22400.00 (0ms ?*RT. ?UPS, TraCI: 9ms, vehicles TOT 15562 ACT 44 BUF 0)                Step 85000 — Target network updated
# Step #26900.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 18692 ACT 54 BUF 0)               Step 86000 — Target network updated
# Step #31400.00 (0ms ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 21817 ACT 53 BUF 1)               Step 87000 — Target network updated
# Step #36900.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 24942 ACT 64 BUF 0)               Step 88000 — Target network updated
# Step #4500  Step 89000 — Target network updatedhicles TOT 31165 ACT 69 BUF 27)            00.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 28133 ACT 71 BUF 3)
# Step #49500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 34303 ACT 67 BUF 15)              Step 90000 — Target network updated
# Step #54000.00 (1ms ~= 1000.00*RT, ~110000.00UPS, TraCI: 20ms, vehicles TOT 36862 ACT 110   Step 91000 — Target network updated
# Step #58500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 40302 ACT 73 BUF 274)             Step 92000 — Target network updated
# Step #63000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 43704 ACT 48 BUF 0)               Step 93000 — Target network updated
# Step #67500.00 (0ms ?*RT. ?UPS, TraCI: 8ms, vehicles TOT 46826 ACT 38 BUF 0)                Step 94000 — Target network updated
# Step #72000.00 (0ms ?*RT. ?UPS, TraCI: 10ms, vehicles TOT 49954 ACT 51 BUF 0)               Step 95000 — Target network updated
# Step #76500.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 53056 ACT 69 BUF 26)              Step 96000 — Target network updated
# Step #81000.00 (0ms ~= 1000.00*RT, ~56000.00UPS, TraCI: 12ms, vehicles TOT 56204 ACT 56 BU  Step 97000 — Target network updated
# Step #85500.00 (0ms ?*RT. ?UPS, TraCI: 12ms, vehicles TOT 59213 ACT 59 BUF 119)             Step 98000 — Target network updated
# Step #94500.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 65508 ACT 60 BUF 74)            ?*RT. ?UPS, TraCI: 11ms, vehicles TOT 62526 ACT 57 BUF 2)               Step 99000 — Target network updated
# Step #99000.00 (1ms ~=RT. ?UPS, TraCI: 15ms, vehicles TOT 68635 ACT 75 BUF 69)              Step 100000 — Target network updated
#   Episode   5 | Steps: 100000 | Epsilon: 0.098 | Waiting: 356.0s | Buffer: 50000
# Step #100000.00 (0ms ?*RT. ?UPS, TraCI: 15ms, vehicles TOT 69406 ACT 78 BUF 66)
#  Retrying in 1 seconds
#
# Seed 1000 complete. Model saved.
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 0 ACT 0 BUF 0)
#
# ===== ALL VANILLA DQN V2 TRAINING COMPLETE =====
#
# Final episode waiting times:
#   Seed 42: 249.0s
#   Seed 123: 889.0s
#   Seed 456: 655.0s
#   Seed 789: 463.0s
#   Seed 1000: 356.0s
